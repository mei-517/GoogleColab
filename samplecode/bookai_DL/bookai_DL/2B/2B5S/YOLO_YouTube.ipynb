# %% [markdown]
# #YOLOv5のインストール

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd /content/yolov5/
# !pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12382, done.
# remote: Total 12382 (delta 0), reused 0 (delta 0), pack-reused 12382
# Receiving objects: 100% (12382/12382), 11.51 MiB | 23.25 MiB/s, done.
# Resolving deltas: 100% (8620/8620), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 15.4 MB/s

# %% [markdown]
# #東京ズーネットYouTubeチャンネル
# ある日のアルン──体重測定編（2021年8月12日撮影）
#
# https://www.youtube.com/watch?v=PhMnCrPIAx0

# %%
# !python detect.py --weights yolov5s.pt --source https://www.youtube.com/watch?v=PhMnCrPIAx0

# %% [markdown]
# #東京ズーネットYouTubeチャンネル
# ジャイアントパンダ「シャンシャン」のようす
#
# https://www.youtube.com/watch?v=PM4mXotqJd8

# %%
# !python detect.py --weights yolov5s.pt --source https://www.youtube.com/watch?v=PM4mXotqJd8
