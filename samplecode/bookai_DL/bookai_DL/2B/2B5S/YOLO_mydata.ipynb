# %% [markdown]
# #YOLOv5のインストール

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd /content/yolov5/
# !pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12382, done.
# remote: Total 12382 (delta 0), reused 0 (delta 0), pack-reused 12382
# Receiving objects: 100% (12382/12382), 11.56 MiB | 10.17 MiB/s, done.
# Resolving deltas: 100% (8618/8618), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 4.3 MB/s

# %% [markdown]
# #dataフォルダの下のmyフォルダの下のすべての画像や動画を対象とした検出

# %%
# !python detect.py --weights yolov5s.pt --source data/mydata
