# %% [markdown]
# #YOLOv5のインストール

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12038, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 12038 (delta 7), reused 17 (delta 5), pack-reused 12018
# Receiving objects: 100% (12038/12038), 11.45 MiB | 30.62 MiB/s, done.
# Resolving deltas: 100% (8339/8339), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 5.2 MB/s

# %% [markdown]
# #dataフォルダの下のimagesフォルダの下のすべての画像を対象とした検出
# トマトのテスト画像アップロード後に行う

# %%
# !python detect.py --source data/images/ --weights yolov5s.pt
# Out:
# ...
# detect: weights=['yolov5s.pt'], source=data/images/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-65-g7a2a118 torch 1.10.0+cu111 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 61.6MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.5 GFLOPs
# image 1/5 /content/yolov5/data/images/apple.jpg: 448x640 7 apples, Done. (0.314s)
# image 2/5 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, Done. (0.330s)
# image 3/5 /content/yolov5/data/images/orange.jpg: 480x640 10 oranges, Done. (0.344s)
# image 4/5 /content/yolov5/data/images/tomato.jpg: 640x640 4 apples, 5 oranges, 1 vase, Done. (0.433s)
# ...

# %% [markdown]
# #学習
# google driveに学習データをアップロード後に行う

# %%
# !python train.py --batch 16 --epochs 200 --data /content/drive/MyDrive/YOLO/MyData/tomato/tomato.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/drive/MyDrive/YOLO/MyData/tomato/tomato.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-65-g7a2a118 torch 1.10.0+cu111 CPU
#
# ...

# %% [markdown]
# #学習モデルを使った検出のテスト
# 先ほどのテスト画像を使う
#
# 「best.pt」を使用する点がポイント

# %%
# !python detect.py --source data/images/ --weights /content/yolov5/runs/train/exp/weights/best.pt

# %% [markdown]
# #学習状態の可視化
# Tensorboardを使用する

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs
